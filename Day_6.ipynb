# %%
#functions
#car(steering, breaks, wheels) # 3 arguments/parameters
#car() # no argument/parameter

# %%
# Type Casting
int(2.3)
# Out:
# 2

# %%
int(2.3, 3.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int(2.3, 3.3)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
# We can type case from all other data type to integer except complex and text string.

# %%
float(10)
# Out:
# 10.0

# %%
float(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float(10,20)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
#
# Out:
# Bad pipe message: %s [b'S\x8e\xeeL\x1ct\x18T\xba\xe0"\xacV\xb3\xf5\xd79\xc8 q\xea\x02\xcd85_\r93\xe0C\xe3U\x80\xa26\xaf\xd49\x92\xf9m\x13\xfd\x0bfv\xd4cG\x03\x00\x1a\xc0+\xc0/\xc0,\xc00\xcc\xa9\xcc\xa8\xc0\t\xc0\x13\xc0\n\xc0\x14\x13\x01\x13\x02\x13\x03\x01\x00\x05A\x00\x0b\x00\x02\x01\x00\xff\x01\x00\x01\x00\x00\x17\x00\x00\x00\x12\x00\x00\x00\x05\x00\x05\x01\x00\x00\x00\x00\x00\n\x00\x0c\x00\n\x11\xec\x00\x1d\x00\x17\x00\x18\x00\x19\x00\r\x00\x1a\x00\x18\x08\x04\x04\x03\x08\x07\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x05\x03\x06\x03\x02\x01\x02\x03\x00+\x00\x05\x04\x03\x04\x03\x03\x003\x04\xea', b'\x11\xec\x04']
# Bad pipe message: %s [b"b?\xbb'\x90,\xa8\xa7\x92\x91\xa8\xe8\x87f\xa8L\xc7/\xaba\x19\xa9U\xb5\x1c\xad<\xdbc\x0eXU\xeb\xb4>`2\x07I\xf6\xa2\xf4\xf3\xb7\xfa5\xbdn \x96T\xc9\xca\xe1l'\xa5j\n\xd7Q.\x13\xf9\xbdS*\x85\x07\x12Z\xe9&\xa5\x1a\xb3v\x9d\x8bu\x1b\xcc\xc8\xd4'\x0b\xd5(l\xc2\xb6~\x92\xe3\x08N\x05\xce\xe9<\xc4\x12\xe0Pm\xb7\x8cD\x80\x8d\x82\xe2)n\x94\x0f\x1a*mL\x137\xf5eYj\x98\x98nJ\xaf\x0b \x0e\xd9\xccBx*(F\xd3ny\x91\x8c_\x83 \xa4i\x13\x0e\x00]\xf4e\x9d=\n#\x1c+\x91M\xd7\xc9\x84\xc6\x15\xac\x8b\x89\xa2\x81U\xd7I\x95\xb20\xbf/8\x90\xb8\x1a{v\x90N"]
# Bad pipe message: %s [b'\x05\xd3\x06_\x80H\xafY\xc5\x93\x86I0:\xbd\xbb\xc6\xa3/\x0b\xa3\xa7\xe8\x99\x88v\xac\xb7lL\xd2q\x8f\x16E "\xfaT\xf8\x08\x14(a\xbf\x13\'(\xec7\xbe\x94\x19<\x9e\xc8\xbf\xb5\xa0\xa2\r\xb0\xb3\xd0\xbb\xbb\xa6\xbaAq8\x8eZ\x8b\x92a%\x84\xb6\xc0?6\\\x0c\x93\xf4\x9b\xf0\xc1/\xbf\xa3\xce\xd4\t\x12\x81%%\xe3\x077\xa6\x96\x97\x05T1N\xe3\x18\x81\xacY>\xd3\x9ck4\x8f\x0c\xd3\x8a\x8b4ur:\n\xff\x19\x81!\xd9G\xe2\x87[#\xb1Vx2\xc4\x9b\xa1\n[ai_A\xc5\x1dh\xbc\x1d4S\xb6@P\x17\x88,.\xd9\xbcf\xf6\x91#\x89\x97\'\x13Q\xb4\x15\x93 rN\xbe\xea\x8f\xc3cg\x02\xf7\x1f\t7\xa0u\xe2RED\xb8#\xf6f$\xdc\x00Oi\xcc\x8d']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 577, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user/aiml/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
