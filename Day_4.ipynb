# %%
print("HI")
# Out:
# HI

# %%
#string
word = "Python"
print(len(word))
# Out:
# 6

# %%
print(word[2])
# Out:
# t

# %%
for i in word:
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# str[starting index : ending index] where ending index value is not included

# %%
str= word[2:4]

# %%
print(str)
# Out:
# th

# %%
print(word[2:])
# Out:
# thon

# %%
print(word[:])
# Out:
# Python

# %%
print(word[-5:-1])
# Out:
# ytho

# %%
a=5
b=10
sum = a + b
print("Sum of a and b is {}".format(sum))
# Out:
# Sum of a and b is 15

# %%
print("Sum of {} and {} is {}".format(a,b,sum))
# Out:
# Sum of 5 and 10 is 15

# %%
print("Sum of {1} & {0} is {2}".format(a,b,sum))
# Out:
# Sum of 10 & 5 is 15

# %%
print(f"sum of {a} and {b} is {sum}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"sum of {a} and {b} is {sum}")
#
# NameError: name 'a' is not defined

# %%
#comments

# %%
#single line comment
''' multi 
line 
comment'''
# Out:
# ' multi \nline \ncomment'

# %%
""" you can use this also """
# Out:
# ' you can use this also '

# %%
# VAriables
# memory location to store the values.
a = 10

# %%
  #fundamental data types
  #int, float, string, boolean
  a = 10
  b = 10.10
  c = "Ten"
  d = True
  print(a,b,c,d)
# Out:
# 10 10.1 Ten True

# %%
#advanced data types
# List, tupple, set

# %%
# privae Variable, it will hide the value.
# it does not hide actually, it means this is no need to use outside class/method.
#it is accessible, it is just type of indecating reader that, this, variable is ment for this module/class/method only.
_z = 5
print(type(_z))
# Out:
# <class 'int'>

# %%
print(_z)
# Out:
# 5

# %%
del(_z)

# %%
print(_z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(_z)
#
# NameError: name '_z' is not defined
