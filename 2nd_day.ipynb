# %% [markdown]
# ## Easy

# %%
#EX 1: Divide 20 by 3 and print only the integer part of the result(floor division)
print(int(20/3))
print(20//3)
# Out:
# 6
# 6

# %%
#EX 2: find the remainder when 27 is divided by 4 using modulus operator.
print(27%4)
# Out:
# 3

# %%
#EX 3: create a variable 'radius' with value 7. calculate the area of circle.
# PI : 3.14
print(3.14*7**2)
# Out:
# 153.86

# %%
#EX 4: convert string "100" to an integer and add 50 to it.
a = "100"
print(int(a) + 50)
# Out:
# 150

# %%
#EX 5: create a variable 'price' with value 99.99. convert it to integer and print the result
#      observe what happens to the decimal part
# write your code below.
price = "99.99"
print(int(price))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       1 #EX 5: create a variable 'price' with value 99.99. convert it to integer and print the result
#       2 #      observe what happens to the decimal part
#       3 # write your code below.
#       4 price = "99.99"
# ----> 5 print(int(price))
#
# ValueError: invalid literal for int() with base 10: '99.99'
