# %% [markdown]
# ## Day 5

# %% [markdown]
# ### ADvance DAta Typs

# %% [markdown]
# #### List
# #### Tupple
# #### Set

# %% [markdown]
# #### Disctionary

# %% [markdown]
# ##### All fundamental data types are immutable
# ##### Advance data types are mutable
# ##### Immutable: We can not replace/modify value in original object
# ##### Once we create object, we can not do modifications.
# ##### Mutable: We can modify the value in the original object. ex. list

# %%
a = 5
id(a) # id means address (memory address)
# Out:
# 140180583633808

# %%
a = 10
id(a)
# Out:
# 140180583633968

# %%
a = (10)
id(a)
# Out:
# 140180583633968

# %%
a = (5)
id(a)
# Out:
# 140180583633808

# %%
l = [1]
id(l)
# Out:
# 137942863451200

# %%
l[0] = 2
print(l)
# Out:
# [2]

# %%
id(l)
# Out:
# 137942863451200
