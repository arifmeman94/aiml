# %%
print("hello")
# Out:
# hello

# %%
print("hi")
# Out:
# hi

# %%
# print is function and ("hello/hi/etc...") this is string in double quotes.
print("Hello")
print("World|")
# Out:
# Hello
# World|

# %%
#same line
print("Hello", "World")
# Out:
# Hello World

# %%
#new line
print("Hello \nworld")
# Out:
# Hello
# world

# %%
#variables
#variables are identifiers that are used to store data values.
#english letters and number and underscore (_) are allowed.
#but variable can not start with numbers/integers 
#variable can start with underscore(_).
age = 20
PI = 3.14
name = "Akash"
city_name = "delhi"
data_none = None

# %%
#Data Types
# integer, string, float, boolean, none.
#you can check data type of variable with help of type
print("Type of age:",type(age))
print("Type of city_name:", type(city_name))
print("Type of data_none: ",type(data_none))
# Out:
# Type of age: <class 'int'>
# Type of city_name: <class 'str'>
# Type of data_none:  <class 'NoneType'>

# %%
#style Guide
#snack case : example : name_first (all lower case and between two words _)
#camel case : example : nameFirst  (first word in small and next in capital)
#pascle case: example : NameFirst  (first word in capital and next in capital)

# %%
a = 5
b = 6
sum = a+b
print(sum)
# Out:
# 11

# %% [markdown]
# ### Easy Python Exercises

# %%
#ex1: Print your name to the console
#Write your code below:
print("Arif")
# Out:
# Arif

# %%
#Ex2: Print the sentence "Python is powerul language."
#Write your code below:
print("Python is powerful language")
# Out:
# Python is powerful language

# %%
#Ex3: Use single print statement to print your name and your favorite color on seprate lines.
# Write your code below
print("Arif\nBlack")
# Out:
# Arif
# Black

# %%
#Ex4: Printthe result of adding 15 and 25
#Write your code below
print(15+25)
# Out:
# 40

# %%
#Ex5: Print the text "Learning Python" Inside a box made of asterisks (*).
#Example:
#******************
#* Learning Python*
#******************
print("*****************")
print("*Learning Python*")
print("*****************")
# Out:
# *****************
# *Learning Python*
# *****************

# %%
#EX6: Write a single line comment above a print statement that says "This is a comment".
#write your code below:
#This is a comment.
print("This is a comment")
# Out:
# This is a comment

# %%
#Ex7: Write multi line comment explaining what the print() fundtion does.
#write your code below
''' print function prints the specified message or output to the screen, or other standard output device. '''
# Out:
# ' print function prints the specified message or output to the screen, or other standard output device. '

# %%
#EX8: Print the result of 100 divided by 4 using the print function.
#Write your code below:
print(100/4)
# Out:
# 25.0

# %%
#EX9: Print three different words on the same file, seprated by hyphen(-).
#Write your code below.
print("One","Two","Three", sep="-")
# Out:
# One-Two-Three

# %%
#Ex 10: Print the word "Python" Five times on the same line.
#Write your code below:
print("Python "*5)
# Out:
# Python Python Python Python Python

# %% [markdown]
# ### Medium Exercises

# %%
#Ex1: Use the help() function to find out what the 'end' parameter does in print().
#Then, print two different strings on the same line without aspace between them using 'end'.
#Write your code below:
help(print)
print("One", end='')
print("Two")
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.
#
# OneTwo

# %%
#Ex2: Print the following exact structure using only One print stamement:
# Number 1
#   Number 2
#     Number 3
#Write your code below:
print("Number 1\n\tNumber 2\n\t\tNumber 3")
print("Number 1\n"," Number 2\n", "   Number 3")
# Out:
# Number 1
# 	Number 2
# 		Number 3
# Number 1
#   Number 2
#     Number 3

# %%
#Ex3: Calculate the area of a rectangle with length 12 and width 7.
#Print the result using formatted string: "The area of the rectangle is: [result]"
#Write your code below:
l = 12
w = 7
print(f"The area of rectangle is: {l*w}")
# Out:
# The area of rectangle is: 84

# %%
#Ex 4: Print the current version of Python you are using.
#Hint: You might need to import 'sys' module and use 'sys.version'.
#Write your code below:
import sys
print(sys.version)
# Out:
# 3.13.5 (main, Jun 11 2025, 15:36:57) [GCC 14.3.0]

# %%
#EX5: Create a "Artistik" signature using characters like |,_,\,/.
#Example:
#  / \
# | o |
#  \ /
# Write your code below.
print(" / \\\n| o |\n \\ /")
# Out:
#  / \
# | o |
#  \ /

# %%
# EX 6: Print a string that contains both single (') and double quotes (")
#   withought using escape characters.
# write your code below
print("'one with single quotes'")
print('"Two with double quotes"')
# Out:
# 'one with single quotes'
# "Two with double quotes"

# %%
#Ex7: print the result of 2 to the power of 10
print(2**10)
# Out:
# 1024

# %%
#EX 8: Use the print function to show the result of bolean comparison.
# write your code below:
print(10>5)
# Out:
# True

# %%
#EX 9: print the first 5 multiples of 7 on single line, seprated by comma and space
# Write your code below:
print(7*1, 7*2, 7*3, 7*4, 7*5, sep=",")
# Out:
# 7,14,21,28,35

# %%
#EX 10: print the word "ERROR" in all caps, and on the next line print it again but indented by 4 spaces.
#write your code below.
print("ERROR")
print("    ERROR")
print("ERROR\n    ERROR")
# Out:
# ERROR
#     ERROR
# ERROR
#     ERROR

# %% [markdown]
# ### Hard Exercises

# %%
#EX1 : print the large letter 'P' using the # character and spaces
# it should look something like this:
# #########
# #       #
# #       #
# #       #
# #########
# #
# #
# #
# #
# write your code below
print("#"*9)
print("#","#", sep=("       "))
print("#","#", sep=("       "))
print("#","#", sep=("       "))
print("#"*9)
print("#\n#\n#\n#")
# Out:
# #########
# #       #
# #       #
# #       #
# #########
# #
# #
# #
# #

# %%
#EX 2: print a representation of a simple "User Login" screen layout
# Include a title, and place holder for username and password.
# ----------------------------------------------------------------
# | User Login                                                   |
# ----------------------------------------------------------------
# | Username: | [                                      ]         |
# |Password : | [                                      ]         |
#_________________________________________________________________
#
# write your code below:
print(""" 
--------------------------------------------------------
| User Login                                            |
--------------------------------------------------------
| Username: | [                                    ]    |
| Pasword : | [                                    ]    |
--------------------------------------------------------
""")
# Out:
#
# --------------------------------------------------------
# | User Login                                            |
# --------------------------------------------------------
# | Username: | [                                    ]    |
# | Pasword : | [                                    ]    |
# --------------------------------------------------------

# %%
#EX 3: use the sep and end parameters of the print() function together
# to print "A", "B", "C" seprated by "->" and ending the line with "!!!".
# write your code below:
print("A ", " B", " C",sep="->", end=" !!!")
# Out:
# A -> B-> C !!!

# %%
#EX 4: print the results of this complex expression: (5 + 3) * (10 / 2) ** 2
# Explain what each part of math operation does
# write your code below:
print("It will follow BODMAS")
print((5 + 3) * (10 / 2) ** 2)
# Out:
# It will follow BODMAS
# 200.0

# %%
#EX 5: print a string that contains a backslash (\) without a causing an error.
# write your code below:
print(r"This \is \n raw \string")
# Out:
# This \is \n raw \string

# %%
print(3+2)
# Out:
# 5

# %%
print(3-2)
# Out:
# 1

# %%
print(3*2)
# Out:
# 6

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3 ** 2)
# Out:
# 9

# %%
print(3%2)
# Out:
# 1

# %%
print(3//2)
# Out:
# 1
